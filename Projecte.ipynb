# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from datetime import datetime

# %%
embassaments_df = pd.read_csv('embassaments.csv')
embassaments_df.head()
# Out:
#           Dia                                          Estació  \
# 0  13/12/2022  Embassament de Sant Ponç (Clariana de Cardener)
# 1  13/12/2022             Embassament de Sau (Vilanova de Sau)
# 2  13/12/2022                   Embassament de Susqueda (Osor)
# 3  13/12/2022                 Embassament de la Baells (Cercs)
# 4  13/12/2022      Embassament de Foix (Castellet i la Gornal)
#
#    Nivell absolut (msnm)  Percentatge volum embassat (%)  Volum embassat (hm3)
# 0                 518.36                            45.4                 11.08
# 1                 390.13                            18.5                 30.65
# 2                 321.88                            43.9                102.18
# 3                 598.41                            28.1                 30.77
# 4                  98.71                            72.2                  2.70

# %%
Sau_df = embassaments.loc[embassaments['Estació'] == 'Embassament de Sau (Vilanova de Sau)'].copy()

# %%
Sau_df.head()
# Out:
#            Dia                               Estació  Nivell absolut (msnm)  \
# 1   13/12/2022  Embassament de Sau (Vilanova de Sau)                 390.13
# 13  12/12/2022  Embassament de Sau (Vilanova de Sau)                 390.07
# 20  11/12/2022  Embassament de Sau (Vilanova de Sau)                 390.05
# 32  10/12/2022  Embassament de Sau (Vilanova de Sau)                 390.04
# 43  09/12/2022  Embassament de Sau (Vilanova de Sau)                 390.03
#
#     Percentatge volum embassat (%)  Volum embassat (hm3)
# 1                             18.5                 30.65
# 13                            18.5                 30.51
# 20                            18.4                 30.48
# 32                            18.4                 30.46
# 43                            18.4                 30.43

# %%
Sau_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8362 entries, 1 to 75337
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Dia                             8362 non-null   object
#  1   Estació                         8362 non-null   object
#  2   Nivell absolut (msnm)           8362 non-null   float64
#  3   Percentatge volum embassat (%)  8359 non-null   float64
#  4   Volum embassat (hm3)            8360 non-null   float64
# dtypes: float64(3), object(2)
# memory usage: 392.0+ KB

# %%
Sau_df['Dia'] = pd.to_datetime(Sau_df['Dia'])
# Out:
# /var/folders/g5/75y4dn_x4c7dx3zch509wxgh0000gn/T/ipykernel_33801/3354471668.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   Sau_df['Dia'] = pd.to_datetime(Sau_df['Dia'])

# %%
Sau_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8362 entries, 1 to 75337
# Data columns (total 5 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Dia                             8362 non-null   datetime64[ns]
#  1   Estació                         8362 non-null   object
#  2   Nivell absolut (msnm)           8362 non-null   float64
#  3   Percentatge volum embassat (%)  8359 non-null   float64
#  4   Volum embassat (hm3)            8360 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(1)
# memory usage: 392.0+ KB

# %%
Sau_df.head()
# Out:
#           Dia                               Estació  Nivell absolut (msnm)  \
# 1  2022-12-13  Embassament de Sau (Vilanova de Sau)                 390.13
# 13 2022-12-12  Embassament de Sau (Vilanova de Sau)                 390.07
# 20 2022-11-12  Embassament de Sau (Vilanova de Sau)                 390.05
# 32 2022-10-12  Embassament de Sau (Vilanova de Sau)                 390.04
# 43 2022-09-12  Embassament de Sau (Vilanova de Sau)                 390.03
#
#     Percentatge volum embassat (%)  Volum embassat (hm3)
# 1                             18.5                 30.65
# 13                            18.5                 30.51
# 20                            18.4                 30.48
# 32                            18.4                 30.46
# 43                            18.4                 30.43

# %%
plt.plot (Sau_df['Dia'] , Sau_df['Volum embassat (hm3)']  , label = ' capacitat ', linewidth = 3 )

# %%
ts = ts.set_index('date')
ts.head(5)
